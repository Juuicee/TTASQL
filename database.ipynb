# %%
# !pip install pandas
# !pip install numpy
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 806.3 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\omnij\miniconda3\lib\site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\omnij\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 4.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/11.5 MB 8.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.5 MB 14.5 MB/s eta 0:00:01
#    -------------- ------------------------- 4.3/11.5 MB 25.0 MB/s eta 0:00:01
#    ------------------------ --------------- 7.0/11.5 MB 32.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 50.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------- ----------------------------- 4.0/15.5 MB 85.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.8/15.5 MB 72.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.9/15.5 MB 48.9 MB/s eta 0:00:01
#    -------------------------------- ------- 12.8/15.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 38.6 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------- 505.5/505.5 kB 33.0 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ---------------------------------------- 345.4/345.4 kB ? eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.1 pytz-2024.1 tzdata-2024.1
# Requirement already satisfied: numpy in c:\users\omnij\miniconda3\lib\site-packages (1.26.4)

# %%
import pandas as pd
import random

# %%
## Define arrays for database columns of car parts

# %%
car_types = [
    'Sedan', 'SUV', 'Hatchback', 'Convertible', 'Coupe', 'Station Wagon', 
    'Minivan', 'Pickup Truck', 'Crossover', 'Roadster', 'Limousine', 'Van', 
    'Compact Car', 'Luxury Car', 'Electric Vehicle (EV)', 'Hybrid Car', 
    'Muscle Car', 'Sports Car', 'Microcar', 'Supercar', 'Off-Road Vehicle', 
    'Hot Hatch', 'Estate Car', '4x4', 'Compact SUV', 'Full-Size SUV', 
    'Luxury SUV', 'Subcompact Car', 'City Car', 'Family Car', 'Executive Car', 
    'Grand Tourer', 'Buggy', 'Amphibious Vehicle', 'Vintage Car', 'Concept Car', 
    'Electric Pickup Truck', 'Electric SUV', 'Compact Pickup Truck', 
    'Full-Size Pickup Truck', 'Commercial Vehicle', 'Armored Car', 'Tow Truck', 
    'Garbage Truck', 'Fire Truck', 'Ambulance', 'Police Car', 'Taxi', 'Hearse', 
    'Ice Cream Truck'
]

# %%
car_parts = [
    'Engine', 'Transmission', 'Brake System', 'Suspension', 'Steering System', 
    'Exhaust System', 'Fuel System', 'Ignition System', 'Electrical System', 
    'Cooling System', 'Air Conditioning System', 'Drivetrain', 'Wheels', 
    'Tires', 'Chassis', 'Body', 'Interior', 'Exterior Lights', 'Windows', 
    'Mirrors', 'Windshield Wipers', 'Audio System', 'Navigation System', 
    'Safety Features', 'Seatbelts', 'Airbags', 'Instrument Cluster', 
    'Dashboard Controls', 'Sunroof/Moonroof', 'Trunk/Hatch', 'Bumpers', 
    'Fenders', 'Grille', 'Doors', 'Hood', 'Tailgate', 'Quarter Panels', 
    'Roof', 'Side Skirts', 'Floor Mats', 'Seats', 'Steering Wheel', 
    'Gearshift', 'Pedals', 'Armrests', 'Cup Holders', 'Glove Compartment', 
    'Center Console', 'Headliner', 'Carpeting', 'Door Handles', 'Trim Pieces', 
    'Emblems/Badges', 'Lights', 'Switches', 'Power Windows', 'Power Door Locks', 
    'Heated Seats', 'Power Seats', 'Cruise Control', 'Bluetooth System', 
    'USB Ports', 'Auxiliary Input', 'Backup Camera', 'Parking Sensors', 
    'Blind Spot Monitoring', 'Lane Departure Warning', 'Collision Avoidance System', 
    'Adaptive Cruise Control', 'Keyless Entry', 'Remote Start', 'Alarm System', 
    'Immobilizer', 'Traction Control', 'Stability Control', 'Anti-lock Braking System (ABS)', 
    'Electronic Stability Control (ESC)', 'Tire Pressure Monitoring System (TPMS)', 
    'Airbag Control Module', 'Engine Control Unit (ECU)', 'Fuel Injector', 
    'Intake Manifold', 'Catalytic Converter', 'Oxygen Sensor', 'Throttle Body', 
    'Radiator', 'Water Pump', 'Thermostat', 'Fan Belt', 'Timing Belt', 'Camshaft', 
    'Crankshaft', 'Pistons', 'Connecting Rods', 'Cylinder Head', 'Valves', 'Valve Cover', 
    'Oil Pan', 'Oil Pump', 'Oil Filter', 'Fuel Pump', 'Fuel Filter', 'Air Filter', 'Spark Plugs', 
    'Ignition Coil', 'Distributor', 'Alternator', 'Starter Motor', 'Battery', 'Flywheel', 
    'Clutch', 'Pressure Plate', 'Throw-out Bearing', 'Flywheel Ring Gear', 'Transmission Control Module', 
    'Shift Solenoid', 'Torque Converter', 'Planetary Gearset', 'Clutch Packs', 'Output Shaft', 
    'Driveshaft', 'Differential', 'Axles', 'Wheel Bearings', 'CV Joints', 'Control Arms', 
    'Ball Joints', 'Struts', 'Shocks', 'Coil Springs', 'Sway Bars', 'Tie Rods', 'Rack and Pinion', 
    'Power Steering Pump', 'Steering Gearbox', 'Steering Column', 'Tie Rod Ends', 'Pitman Arm', 
    'Idler Arm', 'Drag Link', 'Exhaust Manifold', 'Catalytic Converter', 'Muffler', 'Resonator', 
    'Exhaust Pipes', 'Tailpipe', 'Oxygen Sensor', 'Fuel Tank', 'Fuel Pump', 'Fuel Filter', 'Fuel Lines', 
    'Fuel Injector', 'Throttle', 'Throttle Position Sensor', 'Idle Air Control Valve', 'Mass Airflow Sensor', 
    'Intake Manifold', 'Intake Air Temperature Sensor', 'Air Filter', 'PCV Valve', 'EGR Valve', 
    'Breather Filter', 'Ignition Switch', 'Ignition Coil', 'Distributor', 'Spark Plugs', 'Spark Plug Wires', 
    'Ignition Control Module', 'Crankshaft Position Sensor', 'Camshaft Position Sensor', 'Knock Sensor', 
    'Oxygen Sensor', 'MAP Sensor', 'MAF Sensor', 'Throttle Position Sensor', 'Engine Coolant Temperature Sensor', 
    'Vehicle Speed Sensor', 'ABS Control Module', 'ABS Sensors', 'ABS Pump', 'Brake Master Cylinder', 'Brake Booster', 
    'Brake Lines', 'Brake Calipers', 'Brake Pads', 'Brake Rotors', 'Parking Brake Cable', 'Drum Brakes', 
    'Brake Shoes', 'Wheel Cylinder', 'Suspension Springs', 'Shock Absorbers', 'Struts', 'Control Arms', 
    'Bushings', 'Sway Bars', 'Ball Joints', 'Tie Rods', 'Steering Knuckles', 'CV Joints', 'CV Boots', 
    'Halfshafts', 'Wheel Hubs', 'Wheel Bearings', 'Wheel Spindles', 'Wheel Studs', 'Wheel Lugs', 
    'Power Steering Pump', 'Power Steering Fluid', 'Power Steering Hoses', 'Power Steering Gear', 
    'Steering Column', 'Steering Shaft', 'Rack and Pinion', 'Tie Rod Ends', 'Center Link', 'Pitman Arm', 
    'Idler Arm', 'Steering Damper', 'Steering Knuckle', 'Axle Shafts', 'U-Joints', 'Differential Gears', 
    'Differential Bearings', 'Differential Seals', 'Axle Seals', 'Pinion Seal', 'Axle Flange Gasket', 
    'Differential Cover', 'Wheel Bearings', 'Axle Shaft Bearings', 'Hub Assembly', 'Hub Bearings', 
    'Axle Nut', 'Spindle', 'Spindle Nut', 'Spindle Pin', 'Spindle Bushing', 'Spindle Seal', 'Spindle Bearings', 
    'Stub Axle', 'Wheel Studs', 'Wheel Lugs', 'Wheel Hub Assembly', 'Hub Bearings', 'Hub Seal', 'Hub Bolts', 
    'Hub Dust Cap', 'Hub Gasket', 'Wheel Studs', 'Wheel Lugs', 'Wheel Nuts', 'Wheel Hub', 'Hubcap', 
    'Wheel Cover', 'Wheel Center Cap', 'Wheel Trim Ring', 'Wheel Spacer', 'Wheel Adapter', 'Wheel Balancer', 
    'Tire Iron', 'Lug Wrench', 'Tire Pressure Gauge', 'Tire Valve Stem', 'Tire Valve Cap', 'Tire Patch', 
    'Tire Plug', 'Tire Patch Cement', 'Tire Plug Tool', 'Tire Repair Kit', 'Tire Sealant', 'Tire Inflator', 
    'Tire Jack', 'Tire Chains', 'Tire Chains Tensioners', 'Tire Chains Carrying Case', 'Chassis Frame', 
    'Chassis Braces', 'Chassis Mounts', 'Chassis Stiffeners', 'Chassis Reinforcements', 'Chassis Bushings', 
]

# %%
brand_types = [
    'Toyota', 'Honda', 'Ford', 'Chevrolet', 'Nissan', 'BMW', 'Mercedes-Benz', 
    'Audi', 'Volkswagen', 'Hyundai', 'Kia', 'Volvo', 'Subaru', 'Mazda', 
    'Lexus', 'Jeep', 'Tesla', 'Ferrari', 'Porsche', 'Mitsubishi', 'Chrysler', 
    'Dodge', 'Buick', 'Cadillac', 'GMC', 'Acura', 'Infiniti', 'Land Rover', 
    'Jaguar', 'Lincoln', 'Ram', 'Bentley', 'Rolls-Royce', 'McLaren', 'Bugatti', 
    'Lamborghini', 'Maserati', 'Alfa Romeo', 'Fiat', 'MINI', 'Smart', 'Suzuki', 
    'Pontiac', 'Saturn', 'Saab', 'Hummer', 'Oldsmobile', 'Scion', 'Maybach', 
    'Aston Martin', 'Lotus', 'Koenigsegg', 'Genesis', 'Karma', 'Polestar'
]

# %%
weights_kg = [
    ( 'Engine', 200 ),
    ( 'Transmission', 75 ),
    ( 'Brake System', 50 ),
    ( 'Suspension', 100 ),
    ( 'Steering System', 30 ),
    ( 'Exhaust System', 20 ),
    ( 'Fuel System', 30 ),
    ( 'Ignition System', 10 ),
    ( 'Electrical System', 25 ),
    ( 'Cooling System', 30 ),
    ( 'Air Conditioning System', 40 ),
    ( 'Drivetrain', 150 ),
    ( 'Wheels', 20 ),
    ( 'Tires', 25 ),
    ( 'Chassis', 200 ),
    ( 'Body', 300 ),
    ( 'Interior', 50 ),
    ( 'Exterior Lights', 10 ),
    ('Windows', 30),
    ('Mirrors', 5),
    ('Windshield Wipers', 5),
    ('Audio System', 15),
    ('Navigation System', 10),
    ('Safety Features', 50),
    ('Seatbelts', 10),
    ('Airbags', 20),
    ('Instrument Cluster', 10),
    ('Dashboard Controls', 15),
    ('Sunroof/Moonroof', 25),
    ('Trunk/Hatch', 40),
    ('Bumpers', 50),
    ('Fenders', 20),
    ('Grille', 10),
    ('Doors', 50),
    ('Hood', 30),
    ('Tailgate', 40),
    ('Quarter Panels', 30),
    ('Roof', 50),
    ('Side Skirts', 20),
    ('Floor Mats', 5),
    ('Seats', 70),
    ('Steering Wheel', 15),
    ('Gearshift', 10),
    ('Pedals', 10),
    ('Armrests', 10),
    ('Cup Holders', 5),
    ('Glove Compartment', 10),
    ('Center Console', 20),
    ('Headliner', 15),
    ('Carpeting', 20),
    ('Door Handles', 5),
    ('Trim Pieces', 10),
    ('Emblems/Badges', 5),
    ('Lights', 10),
    ('Switches', 5),
    ('Power Windows', 20),
    ('Power Door Locks', 20),
    ('Heated Seats', 30),
    ('Power Seats', 30),
    ('Cruise Control', 20),
    ('Bluetooth System', 10),
    ('USB Ports', 5),
    ('Auxiliary Input', 5),
    ('Backup Camera', 10),
    ('Parking Sensors', 10),
    ('Blind Spot Monitoring', 10),
    ('Lane Departure Warning', 10),
    ('Collision Avoidance System', 20),
    ('Adaptive Cruise Control', 20),
    ('Keyless Entry', 10),
    ('Remote Start', 15),
    ('Alarm System', 10),
    ('Immobilizer', 5),
    ('Traction Control', 20),
    ('Stability Control', 20),
    ('Anti-lock Braking System (ABS)', 30),
    ('Electronic Stability Control (ESC)', 20),
    ('Tire Pressure Monitoring System (TPMS)', 10),
    ('Airbag Control Module', 5),
    ('Engine Control Unit (ECU)', 5),
    ('Fuel Injector', 5),
    ('Intake Manifold', 10),
    ('Catalytic Converter', 15),
    ('Oxygen Sensor', 5),
    ('Throttle Body', 10),
    ('Radiator', 20),
    ('Water Pump', 10),
    ('Thermostat', 5),
    ('Fan Belt', 5),
    ('Timing Belt', 10),
    ('Camshaft', 10),
    ('Crankshaft', 15),
    ('Pistons', 15),
    ('Connecting Rods', 10),
    ('Cylinder Head', 20),
    ('Valves', 10),
    ('Valve Cover', 5),
    ('Oil Pan', 10),
    ('Oil Pump', 10),
    ('Oil Filter', 5),
    ('Fuel Pump', 10),
    ('Fuel Filter', 5),
    ('Air Filter', 5),
    ('Spark Plugs', 5),
    ('Ignition Coil', 5),
    ('Distributor', 10),
    ('Alternator', 10),
    ('Starter Motor', 10),
    ('Battery', 20),
    ('Flywheel', 15),
    ('Clutch', 10),
    ('Pressure Plate', 10),
    ('Throw-out Bearing', 5),
    ('Flywheel Ring Gear', 10),
    ('Transmission Control Module', 5),
    ('Shift Solenoid', 5),
    ('Torque Converter', 10),
    ('Planetary Gearset', 20),
    ('Clutch Packs', 15),
    ('Output Shaft', 10),
    ('Driveshaft', 20),
    ('Differential', 30),
    ('Axles', 20),
    ('Wheel Bearings', 10),
    ('CV Joints', 10),
    ('Control Arms', 15),
    ('Ball Joints', 10),
    ('Struts', 15),
    ('Shocks', 10),
    ('Coil Springs', 15),
    ('Sway Bars', 10),
    ('Tie Rods', 10),
    ('Rack and Pinion', 15),
    ('Power Steering Pump', 15),
    ('Steering Gearbox', 20),
    ('Steering Column', 10),
    ('Tie Rod Ends', 10),
    ('Pitman Arm', 10),
    ('Idler Arm', 10),
    ('Drag Link', 10),
    ('Exhaust Manifold', 10),
    ('Catalytic Converter', 15),
    ('Muffler', 10),
    ('Resonator', 5),
    ('Exhaust Pipes', 10),
    ('Tailpipe', 5),
    ('Oxygen Sensor', 5),
    ('Fuel Tank', 30),
    ('Fuel Pump', 10),
    ('Fuel Filter', 5),
    ('Fuel Lines', 10),
    ('Fuel Injector', 5),
    ('Throttle', 10),
    ('Throttle Position Sensor', 5),
    ('Idle Air Control Valve', 5),
    ('Mass Airflow Sensor', 5),
    ('Intake Manifold', 10),
    ('Intake Air Temperature Sensor', 5),
    ('Air Filter', 5),
    ('PCV Valve', 5),
    ('EGR Valve', 10),
    ('Breather Filter', 5),
    ('Ignition Switch', 5),
    ('Ignition Coil', 5),
    ('Distributor', 10),
    ('Spark Plugs', 5),
    ('Spark Plug Wires', 5),
    ('Ignition Control Module', 5),
    ('Crankshaft Position Sensor', 5),
    ('Camshaft Position Sensor', 5),
    ('Knock Sensor', 5),
    ('Oxygen Sensor', 5),
    ('MAP Sensor', 5),
    ('MAF Sensor', 5),
    ('Throttle Position Sensor', 5),
    ('Engine Coolant Temperature Sensor', 5),
    ('Vehicle Speed Sensor', 5),
    ('ABS Control Module', 10),
    ('ABS Sensors', 5),
    ('ABS Pump', 10),
    ('Brake Master Cylinder', 10),
    ('Brake Booster', 10),
    ('Brake Lines', 5),
    ('Brake Calipers', 10),
    ('Brake Pads', 5),
    ('Brake Rotors', 10),
    ('Parking Brake Cable', 5),
    ('Drum Brakes', 10),
    ('Brake Shoes', 10),
    ('Wheel Cylinder', 5),
    ('Suspension Springs', 15),
    ('Shock Absorbers', 10),
    ('Struts', 15),
    ('Control Arms', 15),
    ('Bushings', 5),
    ('Sway Bars', 10),
    ('Ball Joints', 10),
    ('Tie Rods', 10),
    ('Steering Knuckles', 10),
    ('CV Joints', 10),
    ('CV Boots', 5),
    ('Halfshafts', 15),
    ('Wheel Hubs', 10),
    ('Wheel Bearings', 10),
    ('Wheel Spindles', 10),
    ('Wheel Studs', 5),
    ('Wheel Lugs', 5),
    ('Power Steering Pump', 15),
    ('Power Steering Fluid', 5),
    ('Power Steering Hoses', 5),
    ('Power Steering Gear', 20),
    ('Steering Column', 10),
    ('Steering Shaft', 10),
    ('Rack and Pinion', 15),
    ('Tie Rod Ends', 10),
    ('Center Link', 10),
    ('Pitman Arm', 10),
    ('Idler Arm', 10),
    ('Steering Damper', 5),
    ('Steering Knuckle', 10),
    ('Axle Shafts', 15),
    ('U-Joints', 5),
    ('Differential Gears', 20),
    ('Differential Bearings', 10),
    ('Differential Seals', 5),
    ('Axle Seals', 5),
    ('Pinion Seal', 5),
    ('Axle Flange Gasket', 5),
    ('Differential Cover', 10),
    ('Wheel Bearings', 10),
    ('Axle Shaft Bearings', 10),
    ('Hub Assembly', 15),
    ('Hub Bearings', 10),
    ('Hub Seal', 5),
    ('Hub Bolts', 5),
    ('Hub Dust Cap', 5),
    ('Hub Gasket', 5),
    ('Wheel Studs', 5),
    ('Wheel Lugs', 5),
    ('Wheel Nuts', 5),
    ('Wheel Hub', 10),
    ('Hubcap', 5),
    ('Wheel Cover', 5),
    ('Wheel Center Cap', 5),
    ('Wheel Trim Ring', 5),
    ('Wheel Spacer', 5),
    ('Wheel Adapter', 5),
    ('Wheel Balancer', 10),
    ('Tire Iron', 5),
    ('Lug Wrench', 5),
    ('Tire Pressure Gauge', 5),
    ('Tire Valve Stem', 5),
    ('Tire Valve Cap', 5),
    ('Tire Patch', 5),
    ('Tire Plug', 5),
    ('Tire Patch Cement', 5),
    ('Tire Plug Tool', 5),
    ('Tire Repair Kit', 10),
    ('Tire Sealant', 10),
    ('Tire Inflator', 5),
    ('Tire Jack', 10),
    ('Tire Chains', 20),
    ('Tire Chains Tensioners', 10),
    ('Tire Chains Carrying Case', 5),
    ('Chassis Frame', 200),
    ('Chassis Braces', 20),
    ('Chassis Mounts', 10),
    ('Chassis Stiffeners', 15),
    ('Chassis Reinforcements', 30),
    ('Chassis Bushings', 10),
]

# %%
# Function to generate random part ID
def generate_part_id():
    return random.randint(10000000, 99999999)

def get_weight(car_part):
    try:
        return next(w for part, w in weights_kg if part == car_part)
    except StopIteration:
        # If car part is not found in weights_kg list, return 0
        return 0

# Initialize empty lists to store data
part_data = []

# Define the number of rows for the dataset
num_rows = 600

# Generate random data for each row
for _ in range(num_rows):
    car_type = random.choice(car_types)
    brand = random.choice(brand_types)
    car_part = random.choice(car_parts)
    weight = get_weight(car_part)
    part_id = generate_part_id()
    part_cost = round(random.uniform(3000, 10000), 2)
    num_parts = random.randint(1, 10)
    part_data.append([part_id, car_type, brand, car_part, weight, num_parts, part_cost])

# Create DataFrame from the generated data
columns = ['Part ID', 'Car Type', 'Brand', 'Car Part', 'Weight (kg)', 'Number of Parts', 'Part Cost']
df = pd.DataFrame(part_data, columns=columns)

# %%
df.head()
# Out:
#     Part ID     Car Type     Brand           Car Part  Weight (kg)  \
# 0  97022111  Armored Car  Polestar        Spindle Pin            0
# 1  15684239     Supercar  Maserati  Throw-out Bearing            5
# 2  98617515   Family Car      Ford            Battery           20
# 3  78126019     Supercar     Buick    Steering System           30
# 4  47942241  Compact SUV    Jaguar      Fuel Injector            5
#
#    Number of Parts  Part Cost
# 0                5    4245.60
# 1                5    3964.07
# 2                4    4070.57
# 3                3    3815.85
# 4                2    7769.63

# %%
 # Save the DataFrame to a CSV file
 # df.to_csv('car_parts_data.csv', index=False)

# %%
df2 = pd.read_csv('car_parts_data.csv')
df2.head(50)
# Out:
#      Part ID               Car Type          Brand  \
# 0   37520912           Electric SUV        Hyundai
# 1   44623296            Compact Car     Land Rover
# 2   67206335              Limousine  Mercedes-Benz
# 3   99964721            Vintage Car       Chrysler
# 4   79653593               Roadster        Porsche
# 5   64351485        Ice Cream Truck     Volkswagen
# 6   53197700            Convertible          Buick
# 7   71314969               Microcar       Infiniti
# 8   15047576              Hatchback    Lamborghini
# 9   24000009            Vintage Car            Kia
# 10  49953386                Minivan       Cadillac
# 11  50190152                 Hearse          Buick
# 12  73862516          Garbage Truck            GMC
# 13  73595248             Sports Car     Oldsmobile
# 14  51603241                  Coupe        Bentley
# 15  12494211                    SUV       Maserati
# 16  35433408               City Car          Lotus
# 17  11235239     Commercial Vehicle            Kia
# 18  88924949                 Hearse          Karma
# 19  89351600             Luxury Car         Suzuki
# 20  82112541             Family Car        Maybach
# 21  31140776             Fire Truck        Maybach
# 22  36492767                    Van         Nissan
# 23  29921707           Electric SUV     Volkswagen
# 24  79846636     Commercial Vehicle         Suzuki
# 25  32451899                    SUV          Karma
# 26  26737882             Sports Car         Toyota
# 27  95446193            Vintage Car         Hummer
# 28  15380601               Microcar  Mercedes-Benz
# 29  76539159         Subcompact Car        Genesis
# 30  25077245     Commercial Vehicle         Jaguar
# 31  39392822              Limousine        Ferrari
# 32  94981345               Microcar            BMW
# 33  38200743              Hatchback        Bentley
# 34  37827713          Executive Car        Genesis
# 35  71867321             Sports Car          Mazda
# 36  64945631            Convertible        Maybach
# 37  66036698             Fire Truck  Mercedes-Benz
# 38  39801865                 Hearse            Ram
# 39  25007889             Luxury SUV         Saturn
# 40  87325319                    4x4         Nissan
# 41  71910935   Compact Pickup Truck     Land Rover
# 42  57255076          Garbage Truck         Saturn
# 43  49309007             Family Car            BMW
# 44  82743856             Estate Car     Mitsubishi
# 45  35424906                 Hearse     Oldsmobile
# 46  28657387                    Van       Cadillac
# 47  44056114                    Van     Volkswagen
# 48  80358639  Electric Vehicle (EV)          Mazda
# 49  96813479                  Buggy     Oldsmobile
#
#                              Car Part  Weight (kg)  Number of Parts  \
# 0       Intake Air Temperature Sensor            5                6
# 1          Collision Avoidance System           20                6
# 2                        Tie Rod Ends           10                1
# 3              Tire Chains Tensioners           10                4
# 4                  Chassis Stiffeners           15                2
# 5                   Electrical System           25                5
# 6                           Gearshift           10                3
# 7                    Traction Control           20                8
# 8                       Chassis Frame          200                1
# 9                         ABS Sensors            5                2
# 10                       Brake Rotors           10                4
# 11                    Tire Repair Kit           10                4
# 12                      Brake Booster           10                4
# 13                        Fuel System           30                1
# 14              Airbag Control Module            5                3
# 15                       Wheel Spacer            5                7
# 16              Airbag Control Module            5                6
# 17                          Fuel Pump           10                5
# 18                 Differential Cover           10               10
# 19               Power Steering Fluid            5               10
# 20                         Halfshafts           15                4
# 21                         Fuel Lines           10                6
# 22                         Alternator           10                2
# 23                        Drum Brakes           10                4
# 24                       Heated Seats           30                5
# 25                        Spark Plugs            5                2
# 26                        Side Skirts           20                9
# 27                   Torque Converter           10                1
# 28  Engine Coolant Temperature Sensor            5                5
# 29            Adaptive Cruise Control           20                1
# 30                       Brake Rotors           10                2
# 31                  Glove Compartment           10                5
# 32                    Shock Absorbers           10                9
# 33                  Glove Compartment           10                7
# 34                           Axle Nut            0                8
# 35                       Remote Start           15                6
# 36                        Brake Shoes           10                6
# 37                Power Steering Pump           15                3
# 38                           Axle Nut            0                6
# 39                        Brake Shoes           10                9
# 40                     Wheel Balancer           10                7
# 41             Tire Chains Tensioners           10                3
# 42                   Chassis Bushings           10                2
# 43                             Clutch           10                4
# 44                         Pitman Arm           10                8
# 45                    Rack and Pinion           15                5
# 46                               Roof           50                9
# 47                      Oxygen Sensor            5               10
# 48                            Airbags           20                4
# 49                       Output Shaft           10                8
#
#     Part Cost  Image
# 0     4397.85    NaN
# 1     3358.17    NaN
# 2     8750.13    NaN
# 3     3368.18    NaN
# 4     9056.22    NaN
# 5     5418.50    NaN
# 6     9848.22    NaN
# 7     9610.03    NaN
# 8     4010.95    NaN
# 9     4269.47    NaN
# 10    7695.15    NaN
# 11    8903.65    NaN
# 12    8092.24    NaN
# 13    7635.74    NaN
# 14    3714.19    NaN
# 15    5021.38    NaN
# 16    3275.56    NaN
# 17    6972.92    NaN
# 18    6985.12    NaN
# 19    9252.89    NaN
# 20    7550.89    NaN
# 21    4898.73    NaN
# 22    8621.02    NaN
# 23    4791.37    NaN
# 24    8336.16    NaN
# 25    3788.23    NaN
# 26    7860.91    NaN
# 27    8742.43    NaN
# 28    8896.38    NaN
# 29    4513.67    NaN
# 30    9057.38    NaN
# 31    4307.92    NaN
# 32    4745.11    NaN
# 33    5240.96    NaN
# 34    4224.57    NaN
# 35    3080.33    NaN
# 36    7045.92    NaN
# 37    3768.86    NaN
# 38    9780.21    NaN
# 39    5759.47    NaN
# 40    7596.40    NaN
# 41    8955.01    NaN
# 42    8763.85    NaN
# 43    9557.59    NaN
# 44    6239.58    NaN
# 45    8703.98    NaN
# 46    3374.77    NaN
# 47    6894.96    NaN
# 48    6732.17    NaN
# 49    6146.06    NaN

# %%
# Creating a new column to the dataSet that's empty

# df2['Image'] = ''
# df2.head(5)

# %%
# Adding extra Image column to dataset for future use

# df2.to_csv('car_parts_data.csv', index=False)
